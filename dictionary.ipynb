# %% [markdown]
# hisdict={
#     "crop":"rice",
#     t"variety":"IR-64",
#     "year":2024
# }
# print(thisdict)

# %%
thisdict={
    "crop":"cotton",
    "organic":True,
    "year":2024,
    "irrigation_methods":["drip","sprinkler","flood"]
}
print(thisdict)
# Out:
# {'crop': 'cotton', 'organic': True, 'year': 2024, 'irrigation_methods': ['drip', 'sprinkler', 'flood']}

# %%
farm={
    "crop":"rice",
    "variety":"IR-64",
    "year":2024
}
x=farm.keys()
print(x)
farm["season"]="kharif"
print(x)
# Out:
# dict_keys(['crop', 'variety', 'year'])
# dict_keys(['crop', 'variety', 'year', 'season'])

# %%
thisdict={
    "crop":"cotton",
    "organic":True,
    "year":2024,
    "irrigation_methods":["drip","sprinkler","flood"]
}
x=thisdict.values()
print(x)
# Out:
# dict_values(['cotton', True, 2024, ['drip', 'sprinkler', 'flood']])

# %%
farm={
    "crop":"rice",
    "variety":"IR-64",
    "year":2024
}
x=farm.values()
print(x)
farm["year"]=2022
print(x)
# Out:
# dict_values(['rice', 'IR-64', 2024])
# dict_values(['rice', 'IR-64', 2022])

# %%
x=thisdict.items()
print(x)
tuple2=tuple(thisdict.items())
print(tuple2)
print(x)
x_keys=tuple(thisdict.keys())
x_values=tuple(thisdict.values())
print(x_keys)
print(x_values)
pairs=zip(x_keys,x_values)
print(tuple(pairs))
# Out:
# dict_items([('crop', 'cotton'), ('organic', True), ('year', 2024), ('irrigation_methods', ['drip', 'sprinkler', 'flood'])])
# (('crop', 'cotton'), ('organic', True), ('year', 2024), ('irrigation_methods', ['drip', 'sprinkler', 'flood']))
# dict_items([('crop', 'cotton'), ('organic', True), ('year', 2024), ('irrigation_methods', ['drip', 'sprinkler', 'flood'])])
# ('crop', 'organic', 'year', 'irrigation_methods')
# ('cotton', True, 2024, ['drip', 'sprinkler', 'flood'])
# (('crop', 'cotton'), ('organic', True), ('year', 2024), ('irrigation_methods', ['drip', 'sprinkler', 'flood']))

# %%
thisdict={
    "crop":"cotton",
    "organic":True,
    "year":2024,
    "irrigation_methods":["drip","sprinkler","flood"]
}
if "organic" in thisdict:
  print("yes,'organic' is one of the keys in the distinct distionary")
# Out:
# yes,'organic' is one of the keys in the distinct distionary

# %%
student={
    "name":"anvitha",
    "roll no":45,
    "branch":"CSE",
    "marks":88

}
print("original dictionary:",student)
# Out:
# original dictionary: {'name': 'anvitha', 'roll no': 45, 'branch': 'CSE', 'marks': 88}

# %%
student={
    "name":"anvitha",
    "roll no":45,
    "branch":"CSE",
    "marks":88
}
student_copy=student.copy()
print("copied dictionary:",student_copy)
# Out:
# copied dictionary: {'name': 'anvitha', 'roll no': 45, 'branch': 'CSE', 'marks': 88}

# %%
student={
    "name":"anvitha",
    "roll no":45,
    "branch":"CSE",
    "marks":88
}
removed_value=student.pop("marks")
print("removed_value:",removed_value)
print("after pop();",student)
# Out:
# removed_value: 88
# after pop(); {'name': 'anvitha', 'roll no': 45, 'branch': 'CSE'}

# %%
student={
    "name":"anvitha",
    "roll no":45,
    "branch":"CSE",
    "marks":88
}
last_item=student.popitem()
print("after popitem()",student)
# Out:
# after popitem() {'name': 'anvitha', 'roll no': 45, 'branch': 'CSE'}

# %%
student={
    "name":"anvitha",
    "roll no":45,
    "branch":"CSE",
    "marks":88
}
student.update({"year":2,"branch":"AI&ML"})
print ("after update()",student)
# Out:
# after update() {'name': 'anvitha', 'roll no': 45, 'branch': 'AI&ML', 'marks': 88, 'year': 2}

# %%
student={
    "name":"anvitha",
    "roll no":45,
    "branch":"CSE",
    "marks":88
}
student.clear()
print("after clear()",student)
# Out:
# after clear() {}

# %%
student={
    "name":"anvitha",
    "roll no":45,
    "branch":"CSE",
    "marks":88
}
del student
# The 'student' variable has been deleted, so printing it would result in a NameError.
# print("after del():",student)

# %%
student={
    "name":"anvitha",
    "marks":{"maths":88,"science":92},
}
x=student["marks"]["maths"]
print("maths:",x)
x=student["marks"]["science"]
print(x)
# Out:
# maths: 88
# 92

# %%
crops = ["Rice", "Wheat", "Maize", "Cotton"]

for plot_no, crop in enumerate(crops):
    print("Plot", plot_no, ":", crop)
# Out:
# Plot 0 : Rice
# Plot 1 : Wheat
# Plot 2 : Maize
# Plot 3 : Cotton
