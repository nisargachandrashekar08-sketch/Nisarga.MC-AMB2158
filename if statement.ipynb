# %%
soil_moisture=int(input("enter soil moisture percentage:"))
if soil_moisture<40:
  print("irrigation is required")
else:
    print("soil moisture is sufficient")
# Out:
# enter soil moisture percentage:45
# soil moisture is sufficient

# %%
rainfall=float(input("enter rainfall in mm:"))
if rainfall<500:
  print("suitable crop:millet")
elif rainfall<1000:
  print ("suitable crop:rice")
else:
  print("suitable crop:sugarcane")
# Out:
# enter rainfall in mm:1500
# suitable crop:sugarcane

# %%
season=input("enter season(kharif/rabi):").lower()
rainfall=int(input("enter rainfall in mm:"))
if season=="kharif":
  if rainfall>600:
    print("grow rice")
  else:
   print("grow pulses")
else:
  print("grow wheat")
# Out:
# enter season(kharif/rabi):rabi
# enter rainfall in mm:700
# grow wheat

# %%
temperature=28
humidity=70
if temperature>25 and humidity>60:
  print("high chance of disease")
# Out:
# high chance of disease

# %%
yield_value=50
result="good yield"if yield_value>70 else "poor yield"

# %%
#===CONTROL STRUCTURES:IF-ELSE===
#1.simple if statement
print("===simple if===")
soil_moisture=25 #percentage
if soil_moisture<30:
  print("soil is dry!irrigation needed.")
# Out:
# ===simple if===
# soil is dry!irrigation needed.

# %%
#2.if-else(two options)
print("===if-else===")
temperature=38
if temperature>35:
  print("high temperature alert!")
  print("consider shade nets for sensitive crops")
else:
  print("temperature is normal")
# Out:
# ===if-else===
# high temperature alert!
# consider shade nets for sensitive crops

# %%
#3.if-elif-else(multiple options)
print("\n===if-elif===")
soil_ph=5.5
if soil_ph<5.5:
  print("soil is acidic")
  print("recommendation:add lime")
elif soil_ph>7.5:
  print("soil is too alkaline")
  print("recommendation:add sulfur")
else:
  print("soil ph is in optimum range(5.5-7.5)")
# Out:
# ===if-elif===
# soil ph is in optimum range(5.5-7.5)

# %%
#4.crop recommendation system
print("\n===crop recommendation system===")
rainfall=150 #mm average
soil_type="loamy"
if rainfall>200 and soil_type=="clay":
  crop="rice"
elif rainfall>100 and soil_type is ["loamy","sandy loamy"]:
  crop="wheat"
elif rainfall<80:
  crop="millet(drought resistant)"
else:
  crop="mixed vegetables"
print(f"recommended crop:{crop}")
# Out:
# ===crop recommendation system===
# recommended crop:mixed vegetables

# %%
#5.nested if(decisions within decisions)
print("\n===irrigation decision system===")
moisture=35
rain_forecast=True
last_irrigation_days=3
if moisture<40:
  if rain_forecast:
    print("moisture low,but rain expected")
    print("action:wait for rain")
  else:
    if last_irrigation_days>2:
      print("irrigate now!")
    else:
      print("check again tomorrow")
else:
  print("moisture adequate,no irrigation needed")
# Out:
# ===irrigation decision system===
# moisture low,but rain expected
# action:wait for rain

# %%
#6.grade crop quality
print("\n===crop quality grading===")
weight=85 #grams per fruit
blemishes=0
color_score=9 #out of 10
if weight>=80 and blemishes==0 and color_score>=8:
  grade="A(premium)"
elif weight>=60 and blemishes<=2 and color_score>=6:
  grade="B(standard)"
elif weight>=40:
  grade="C(processing)"
else:
  grade="reject"
  print(f"crop grade:{grade}")
# Out:
# ===crop quality grading===

# %%
#===for loop===
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(1,11,2):
  print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
crops=["rice","wheat","maize"]
for crop in crops:
  print(crop)
# Out:
# rice
# wheat
# maize

# %%
count=1
while count<=5:
  print(count)
  count+=1
  print("end of the programme")
# Out:
# 1
# end of the programme
# 2
# end of the programme
# 3
# end of the programme
# 4
# end of the programme
# 5
# end of the programme
