# %%
crops=["wheat","rice","maize"]
yield_per_acre=[20,30,40]
area=10
for i in range(len(crops)):
 total=yield_per_acre[i]*area
 print(crops[i],"total yield:",total,"quintals")
# Out:
# wheat total yield: 200 quintals
# rice total yield: 300 quintals
# maize total yield: 400 quintals

# %%
rainfall=[100,20,30,40,59]
print("maximum rainfall:",max(rainfall))
print("minimum rainfall:",min(rainfall))
average=sum(rainfall)/len(rainfall)
print("average rainfall:",average)
# Out:
# maximum rainfall: 100
# minimum rainfall: 20
# average rainfall: 49.8
