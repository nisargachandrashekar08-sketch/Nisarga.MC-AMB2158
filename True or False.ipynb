# %%
crops=["rice","wheat","maize"]
print("rice in crop:","rice" in crops)
print("barley in crop:","barely"in crops)
print("barley not in crop:","barley" not in crops)
# Out:
# rice in crop: True
# barley in crop: False
# barley not in crop: True
