# %%
a=10
print("initial value:",a)
a+=5
print("after+=:",a)
a-=3
print("after-=:",a)
a*=3
print("after*=:",a)
a/=4
print("after/=:",a)
a//=2
print("after//=",a)
a%=3
print("after%=",a)
a**=2
print("after**=",a)
# Out:
# initial value: 10
# after+=: 15
# after-=: 12
# after*=: 36
# after/=: 9.0
# after//= 4.0
# after%= 1.0
# after**= 1.0
