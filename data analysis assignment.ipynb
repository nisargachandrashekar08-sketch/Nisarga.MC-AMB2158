# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-aece3d90-8262-4cf7-9b12-230b30d0ddd7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-aece3d90-8262-4cf7-9b12-230b30d0ddd7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
def load_data(file_name):
  crops=[]
  file=open(file_name,"r")
  for line in file:
    line=line.strip()
    if line:
     data=line.split(",")
    crop={
        "name":data[0],
        "season":data[1],
        "area":float(data[2]),
        "yield":float(data[3]),
        "cost":float(data[4]),
        "revenue":float(data[5])
  }
    crops.append(crop)
  file.close()
  return crops


def kharif_seasonal_crop(crops):
  kharif_crop=[]
  for crop in crops:
    if crop["season"]=="kharif":
     print(crop["name"])
  return kharif_crop
  kharif[season].append(crop[0])


def non_kharif_seasonal_crop(crops):
  non_kharif_crop=[]
  for crop in crops:
    if crop["season"]=="rabi":
      print(crop["name"])
  return non_kharif_crop
  rabi[season].append(crop[0])


def calculate_profit(crop):
  return crop["revenue"]-crop["cost"]

def display_profit(crops):
  print("\ncrop profits:")
  for crop in crops:
    profit=calculate_profit(crop)
    print(crop["name"],"-",profit)

def total_area(crops):
  total_area=sum(crop["area"]for crop in crops)
  print(total_area)

def average_yield(crops):
  average_yield=sum(crop["yield"]for crop in crops)/len(crops)
  print(average_yield)


def average_field_yield(crops):
  for crop in crops:
    average_field_yield=0
    average_field_yield+=crop["yield"]/len[crops]
  return average_field_yield

def main():
   input_file="crop (1).txt"
   output_file="analysis_report.txt"
   crops=load_data(input_file)
   print(crops)

   print("\n-----kharif seasonal crops----")
   kharif_seasonal_crop(crops)

   print("\n----non kharif seasonal crops----")
   non_kharif_seasonal_crop(crops)

   print("\n----display profit------")
   display_profit(crops)

   print("\n----total area----")
   total_area(crops)

   print("\n----average yeild----")
   average_yield(crops)

   print("\n----average field yeild----")
   (crops)

main()
# Out:
# [{'name': 'rice', 'season': 'kharif', 'area': 10.0, 'yield': 40.0, 'cost': 8000.0, 'revenue': 45000.0}, {'name': 'wheat', 'season': 'rabi', 'area': 8.0, 'yield': 30.0, 'cost': 7000.0, 'revenue': 28000.0}, {'name': 'maize', 'season': 'kharif', 'area': 6.0, 'yield': 25.0, 'cost': 6000.0, 'revenue': 32000.0}, {'name': 'cotton', 'season': 'kharif', 'area': 12.0, 'yield': 50.0, 'cost': 9000.0, 'revenue': 36000.0}, {'name': 'pulses', 'season': 'rabi', 'area': 5.0, 'yield': 20.0, 'cost': 5000.0, 'revenue': 11000.0}, {'name': 'groundnut', 'season': 'kharif', 'area': 7.0, 'yield': 28.0, 'cost': 6500.0, 'revenue': 18000.0}, {'name': 'mustard', 'season': 'rabi', 'area': 6.0, 'yield': 24.0, 'cost': 6000.0, 'revenue': 15000.0}]
#
# -----kharif seasonal crops----
# rice
# maize
# cotton
# groundnut
#
# ----non kharif seasonal crops----
# wheat
# pulses
# mustard
#
# ----display profit------
#
# crop profits:
# rice - 37000.0
# wheat - 21000.0
# maize - 26000.0
# cotton - 27000.0
# pulses - 6000.0
# ...
