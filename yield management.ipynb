# %%
print("/n crop yield management system")
def collect_yields():
  yields = []
  n=int(input("enter the number of fields:"))
  for i in range(n):
    value=int(input("enter the yield"))
    yields.append(value)
  return yields
data=collect_yields()
print("collected yields:",data)
def average_yield(yields):
  total=sum(yields)
  return(total/len(yields))
  crop_yield=collected_yields()
  avg=average_yield(crop_yields)
  print("average_yield:",avg)
average_yield(yields)


3
# Out:
# /n crop yield management system
# enter the number of fields:3
# enter the yield4
# enter the yield45
# enter the yield67
# collected yields: [4, 45, 67]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1849175545.py in <cell line: 0>()
#      15   avg=average_yield(crop_yields)
#      16   print("average_yield:",avg)
# ---> 17 average_yield(yields)
#      18
#      19
#
# NameError: name 'yields' is not defined
