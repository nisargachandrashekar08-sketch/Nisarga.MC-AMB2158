# %%
yield_data=[
    ["rice",3200],
    ["wheat",2800],
    ["maize",4000]
]
for crop in yield_data:
  print(crop[0],"yeld:",crop[1],"kg/hectare")
# Out:
# rice yeld: 3200 kg/hectare
# wheat yeld: 2800 kg/hectare
# maize yeld: 4000 kg/hectare

# %%
crop_plan=[
    ["kharif",["rice","maize"]],
    ["rabi",["wheat",'gram']],
    ["zaid",["vegetables"]]
]
print(crop_plan[0])
print(crop_plan[1])
print(crop_plan[0][1])
# Out:
# ['kharif', ['rice', 'maize']]
# ['rabi', ['wheat', 'gram']]
# ['rice', 'maize']

# %%
expenses=[
    ["day1",[1200,500,300]],
    ["day2",[1500,400,600]],
    ["day3",[1000,700,200]]
]
print(expenses[0])
for day in expenses:
  print("day[0],total:",sum(day[1]))
# Out:
# ['day1', [1200, 500, 300]]
# day[0],total: 2000
# day[0],total: 2500
# day[0],total: 1900

# %%
def expenses_mode():
  expenses=[]
  number_of_days=int(input("enter number of days:"))
  for i in range(number_of_days):
    day_name=input(f"enter the day name:")
    seed_cost=int(input("enter the seed cost:"))
    fertilizer_cost=int(input("enter the fertilizer cost:"))
    labour_cost=int(input("enter the labour cost:"))
    expenses.append([day_name,[seed_cost,fertilizer_cost,labour_cost]])
  return expenses

total_expenditure=expenses_mode()
print("daily expenses:")
for expenditure in total_expenditure:
  print(expenditure[0],"expenses are",expenditure[1])
# Out:
# enter number of days:3
# enter the day name:monday
# enter the seed cost:45
# enter the fertilizer cost:34
# enter the labour cost:89
# enter the day name:tuesday
# enter the seed cost:45
# enter the fertilizer cost:25
# enter the labour cost:70
# enter the day name:wednesday
# enter the seed cost:47
# enter the fertilizer cost:48
# enter the labour cost:90
# daily expenses:
# monday expenses are [45, 34, 89]
# tuesday expenses are [45, 25, 70]
# wednesday expenses are [47, 48, 90]

# %%
thistuple=("apple","banana","cherry","appale","cherry")
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'appale', 'cherry')

# %%
thistuple=("apple","banana","cherry","appale","cherry")
print(thistuple)
# Out:
# 5

# %%
thistuple=("apple",)
print(thistuple)
# Out:
# ('apple',)

# %%
fruits=("apple","banana","cherry")
(green,yellow,red)=fruits
print(green)
print(yellow)
print(red)
# Out:
# apple
# banana
# cherry

# %%
ses_mode()def expenses_mode():
  expenses=[]
  number_of_days=int(input("enter number of days:"))
  for i in range(number_of_days):
    day_name=input(f"enter the day name:")
    seed_cost=int(input("enter the seed cost:"))
    fertilizer_cost=int(input("enter the fertilizer cost:"))
    labour_cost=int(input("enter the labour cost:"))
    expenses.append([day_name,[seed_cost,fertilizer_cost,labour_cost]])
  return expenses

total_expenditure=expen
print("daily expenses:")
for expenditure in total_expenditure:
  print(expenditure[0],"expenses are",expenditure[1])
  for day in expenses:
    print("day[0],total:",sum(day[1]))
# Out:
# enter number of days:3
# enter the day name:mon
# enter the seed cost:2
# enter the fertilizer cost:3
# enter the labour cost:4
# enter the day name:tues
# enter the seed cost:6
# enter the fertilizer cost:7
# enter the labour cost:8
# enter the day name:wed
# enter the seed cost:9
# enter the fertilizer cost:5
# enter the labour cost:34
# daily expenses:
# mon expenses are [2, 3, 4]
# day[0],total: 2000
# day[0],total: 2500
# day[0],total: 1900
# tues expenses are [6, 7, 8]
# day[0],total: 2000
# day[0],total: 2500
# day[0],total: 1900
# wed expenses are [9, 5, 34]
# day[0],total: 2000
# day[0],total: 2500
# day[0],total: 1900
